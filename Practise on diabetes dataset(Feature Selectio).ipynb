# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
import seaborn as sb
from pandas import set_option

# %%
File_Path = 'C:/Users/User/Documents/WORK SPACE/'
File_Name = 'diabetes .csv'

# %%
data = pd.read_csv(File_Path + File_Name)

# %%
data.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
#checking for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
#checking the number of columns in my data set
len(data.columns)
# Out:
# 14

# %%
set(data.Gender)
# Out:
# {'F', 'M', 'f'}

# %%
set(data.CLASS)
# Out:
# {'N', 'N ', 'P', 'Y', 'Y '}

# %%
#data.plot(kind = 'density' subplots = True, layout =(6,3), sharex = False, figsize =(20,20))
#pyplot.show()

# %%
df = data[data['Gender'] == 'f']

# %%
df
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 991  195       4543      f   55   4.1  34   13.9   5.4  1.6  1.6  3.1   0.7
#
#       BMI CLASS
# 991  33.0     Y

# %%
df = data['Gender'].values
print(df)
# Out:
# ['F' 'M' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'F' 'F'
#  'F' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'M' 'F' 'F' 'M' 'M' 'F' 'F' 'F'
#  'F' 'M' 'M' 'F' 'F' 'F' 'M' 'M' 'F' 'M' 'M' 'M' 'F' 'F' 'M' 'F' 'M' 'F'
#  'F' 'F' 'F' 'F' 'F' 'F' 'F' 'M' 'M' 'M' 'F' 'M' 'F' 'F' 'M' 'F' 'M' 'M'
#  'F' 'F' 'F' 'M' 'F' 'M' 'F' 'F' 'F' 'F' 'F' 'M' 'M' 'M' 'F' 'F' 'F' 'M'
#  'M' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'M' 'M' 'F' 'F' 'M' 'M' 'M' 'M' 'M' 'M'
#  'F' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'M' 'F' 'M' 'M' 'F' 'F' 'M' 'F' 'M' 'F'
#  'M' 'M' 'M' 'F' 'F' 'F' 'M' 'M' 'M' 'F' 'F' 'F' 'F' 'M' 'M' 'M' 'M' 'M'
#  'M' 'M' 'F' 'M' 'F' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'M' 'M' 'M' 'M' 'M' 'M'
#  'M' 'M' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'F' 'F' 'M' 'F' 'M' 'F' 'F' 'M' 'M'
#  'F' 'F' 'F' 'M' 'F' 'M' 'M' 'M' 'M' 'M' 'M' 'F' 'M' 'M' 'M' 'M' 'M' 'M'
#  'M' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'F' 'M' 'F' 'F' 'F' 'M' 'F' 'F' 'F'
#  'M' 'M' 'F' 'M' 'M' 'M' 'F' 'F' 'M' 'F' 'M' 'M' 'M' 'F' 'M' 'F' 'M' 'M'
# ...

# %%
df[991] = 'F'

# %%
data['Gender'] = df

# %%
data
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
set(data.Gender)
# Out:
# {'F', 'M'}

# %%
set(data.CLASS)
# Out:
# {'N', 'N ', 'P', 'Y', 'Y '}

# %%
df1 = data[data['CLASS'] == 'N ']

# %%
df1
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 102  435      34241      M   38   6.1  83    5.4   4.5  1.7  0.9  2.8   0.8
#
#       BMI CLASS
# 102  24.6    N

# %%
df1 = data['CLASS'].values
df1
# Out:
# array(['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N ', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
df1[102] = 'N'

# %%
data['CLASS'] = df1

# %%
set(data.CLASS)
# Out:
# {'N', 'P', 'Y', 'Y '}

# %%
df2 = data[data['CLASS'] == 'Y ']
df2
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y

# %%
df2 = data['CLASS'].values
df2
# Out:
# array(['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
df2[996:1000] = 'Y'

# %%
set(data.CLASS)
# Out:
# {'N', 'P', 'Y'}

# %%
data.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
#changing categorical data to numerical data in Gender and class columns using the .getdummies method
dfx = pd.get_dummies(data.loc[:,['Gender', 'CLASS']])

# %%
#concatinating the dummy data  with the original data
dfx1 = pd.concat([data,dfx], axis = 1)

# %%
dfx1
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
# ...

# %%
#keeping only the transformed dummy data
dfx2 = pd.get_dummies(data, columns =['Gender','CLASS'])

# %%
dfx2
# Out:
#       ID  No_Pation  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# 0    502      17975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1    735      34221   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2    420      47975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3    680      87656   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4    504      34223   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..   ...        ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995  200     454317   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996  671     876534   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997  669      87654   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998   99      24004   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999  248      24054   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
#      Gender_F  Gender_M  CLASS_N  CLASS_P  CLASS_Y
# ...

# %%
dfx2.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
#Checking the length of my features
len(dfx2.columns)
# Out:
# 17

# %%
#Rescaling my data on a range of 0-1
#first separating dependent data frorm independent data that is X an Y
array = dfx2.values
X = array[:,0:14]
Y = array[:,14:]

# %%
dfx3 = MinMaxScaler(feature_range = (0,1))
rescaledX =dfx3.fit_transform(X)

# %%
dfx4 = pd.DataFrame(rescaledX)
dfx4.columns =['ID','No_Pation','AGE','Urea','Cr','HbA1c','Chol','TG','HDL','LDL','VLDL','BMI','Gender_F','Gender_M']

# %%
dfx4
# Out:
#            ID  No_Pation       AGE      Urea        Cr     HbA1c      Chol  \
# 0    0.627034   0.000237  0.508475  0.109375  0.050378  0.264901  0.407767
# 1    0.918648   0.000452  0.101695  0.104167  0.070529  0.264901  0.359223
# 2    0.524406   0.000634  0.508475  0.109375  0.050378  0.264901  0.407767
# 3    0.849812   0.001160  0.508475  0.109375  0.050378  0.264901  0.407767
# 4    0.629537   0.000452  0.220339  0.171875  0.050378  0.264901  0.475728
# ..        ...        ...       ...       ...       ...       ...       ...
# 995  0.249061   0.006021  0.864407  0.273438  0.114610  0.403974  0.728155
# 996  0.838548   0.011618  0.186441  0.065104  0.068010  0.754967  0.398058
# 997  0.836045   0.001160  0.169492  0.171875  0.094458  0.384106  0.398058
# 998  0.122653   0.000317  0.305085  0.138021  0.066751  0.384106  0.514563
# 999  0.309136   0.000317  0.576271  0.117188  0.076826  0.397351  0.368932
#
# ...

# %%
dfx4.describe()
# Out:
#                 ID    No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.424906     0.003585     0.568271     0.120436     0.079273
# std       0.300873     0.044817     0.149140     0.076437     0.075548
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.156133     0.000317     0.525424     0.083333     0.052897
# 50%       0.374844     0.000454     0.593220     0.106771     0.068010
# 75%       0.687422     0.000600     0.661017     0.135417     0.084383
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.488819     0.472118     0.151823     0.103582     0.240603
# std       0.167815     0.126382     0.103791     0.068084     0.116156
# ...

# %%
dfx2
# Out:
#       ID  No_Pation  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# 0    502      17975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1    735      34221   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2    420      47975   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3    680      87656   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4    504      34223   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..   ...        ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 995  200     454317   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0
# 996  671     876534   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 997  669      87654   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 998   99      24004   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5
# 999  248      24054   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
#      Gender_F  Gender_M  CLASS_N  CLASS_P  CLASS_Y
# ...

# %%
#Standardising my data
array = dfx4.values
X = array[:,0:14]
stan = StandardScaler().fit(X)
StanX = stan.transform(X)

# %%
dfx5 = pd.DataFrame(StanX, columns = ['ID','No_Pation','AGE','Urea','Cr','HbA1c','Chol','TG','HDL','LDL','VLDL','BMI','Gender_F','Gender_M'])

# %%
dfx5.describe()
# Out:
#                  ID     No_Pation           AGE          Urea            Cr  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   1.929568e-16  4.871104e-18  3.043329e-16  1.273981e-16  1.727785e-18
# std    1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00
# min   -1.412950e+00 -8.003050e-02 -3.812235e+00 -1.576421e+00 -1.049842e+00
# 25%   -8.937585e-01 -7.294548e-02 -2.874413e-01 -4.856476e-01 -3.493135e-01
# 50%   -1.664742e-01 -6.988790e-02  1.673709e-01 -1.788675e-01 -1.491625e-01
# 75%    8.729492e-01 -6.663590e-02  6.221830e-01  1.960860e-01  6.766770e-02
# max    1.912373e+00  2.224434e+01  2.896244e+00  1.151286e+01  1.219348e+01
#
#               HbA1c          Chol            TG           HDL           LDL  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   7.849277e-16  4.101164e-16  1.613154e-16 -3.713696e-17 -1.478817e-16
# ...

# %%
array = dfx5.values
X = array[:,0:14]
normdf = Normalizer().fit(X)
normdfx = normdf.transform(X)

# %%
normdfx1 = pd.DataFrame(normdfx)
normdfx1.columns = ['ID','No_Pation','AGE','Urea','Cr','HbA1c','Chol','TG','HDL','LDL','VLDL','BMI','Gender_F','Gender_M']

# %%
normdfx1
# Out:
#            ID  No_Pation       AGE      Urea        Cr     HbA1c      Chol  \
# 0    0.191221  -0.021265 -0.114124 -0.041189 -0.108868 -0.379797 -0.144932
# 1    0.374236  -0.015942 -0.713442 -0.048540 -0.026396 -0.304290 -0.203713
# 2    0.095467  -0.019006 -0.115744 -0.041774 -0.110414 -0.385190 -0.146990
# 3    0.379021  -0.014519 -0.107606 -0.038837 -0.102651 -0.358107 -0.136655
# 4    0.178138  -0.018309 -0.611040  0.176262 -0.100179 -0.349484  0.007481
# ..        ...        ...       ...       ...       ...       ...       ...
# 995 -0.149526   0.013907  0.508004  0.512111  0.119666 -0.129350  0.518306
# 996  0.250670   0.032682 -0.466808 -0.131988 -0.027183  0.289171 -0.106846
# 997  0.344722  -0.013648 -0.674533  0.169768  0.050706 -0.157410 -0.147830
# 998 -0.211447  -0.015350 -0.371438  0.048423 -0.034889 -0.131336  0.070689
# 999 -0.202839  -0.038436  0.028277 -0.022404 -0.017075 -0.287327 -0.430404
#
# ...

# %%
normdfx1.plot(kind = 'density', subplots = True, layout = (6,3), sharex = False, figsize = (20,20))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
dfx2.duplicated().sum()
# Out:
# 0

# %%
#dfx2['CLASS_N','CLASS_P','CLASS_Y'] = normdfx1['CLASS_N','CLASS_P','CLASS_Y']

# %%
normdfx1.head()
# Out:
#          ID  No_Pation       AGE      Urea        Cr     HbA1c      Chol  \
# 0  0.443426   0.000167  0.359583  0.077348  0.035626  0.187332  0.288365
# 1  0.628083   0.000309  0.069529  0.071219  0.048221  0.181114  0.245602
# 2  0.382318   0.000462  0.370704  0.079740  0.036728  0.193126  0.297283
# 3  0.556898   0.000760  0.333213  0.071676  0.033014  0.173594  0.267217
# 4  0.467129   0.000335  0.163496  0.127535  0.037381  0.196562  0.353000
#
#          TG       HDL       LDL      VLDL       BMI  Gender_F  Gender_M
# 0  0.031430  0.160391  0.081031  0.008105  0.122988  0.707180  0.000000
# 1  0.055709  0.063436  0.128194  0.009795  0.095124  0.000000  0.683704
# 2  0.032402  0.165352  0.083537  0.008356  0.126791  0.729050  0.000000
# 3  0.029125  0.148629  0.075089  0.007511  0.113969  0.655319  0.000000
# 4  0.038475  0.045898  0.131399  0.006378  0.051619  0.000000  0.742020

# %%
set_option('display.width', 100)
plt.figure(figsize = (10,10))
sb.heatmap(normdfx1.corr(), annot = True)
# Out:
# <AxesSubplot:>
