# %%
#Importing all the necessary packages I will need in this particular project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
#File loading....
FilePath = "C:/Users/User/Documents/WORK SPACE/"
FileName = "Churn_Train.csv"
df = pd.read_csv(FilePath + FileName)

# %%
df.head(10)
#Returns the first 10 rows plus the header...by default it only returns  5 rows.
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    NV           125.0  area_code_510                 no              no
# 1    HI           108.0  area_code_415                 no              no
# 2    DC            82.0  area_code_415                 no              no
# 3    HI             NaN  area_code_408                 no             yes
# 4    OH            83.0  area_code_415                 no              no
# 5    MO            89.0  area_code_415                 no              no
# 6    NC           135.0  area_code_415                 no              no
# 7    PA            28.0  area_code_415                 no              no
# 8    IA            86.0  area_code_408                 no              no
# 9    IN            65.0  area_code_415                 no              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                    0.0             2013.4             99.0
# ...

# %%
df.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     2832.000000            3133.000000        3133.000000
# mean        97.321328               7.332589         418.947048
# std         47.874422              13.756056         626.315020
# min       -209.000000             -10.000000           0.000000
# 25%         72.000000               0.000000         149.300000
# 50%        100.000000               0.000000         190.500000
# 75%        127.000000              16.000000         237.800000
# max        243.000000              51.000000        2185.100000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      3133.000000       3133.000000        3032.000000      3133.000000
# mean        100.331631         30.628455         324.258872       100.128631
# std          20.039364          9.275752         320.129372        19.899854
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
df.info()
#Gives a slick information  about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          3333 non-null   object
#  1   account_length                 2832 non-null   float64
#  2   area_code                      3333 non-null   object
#  3   international_plan             3333 non-null   object
#  4   voice_mail_plan                3333 non-null   object
#  5   number_vmail_messages          3133 non-null   float64
#  6   total_day_minutes              3133 non-null   float64
#  7   total_day_calls                3133 non-null   float64
#  8   total_day_charge               3133 non-null   float64
#  9   total_eve_minutes              3032 non-null   float64
#  10  total_eve_calls                3133 non-null   float64
#  11  total_eve_charge               3133 non-null   float64
# ...

# %%
#Check for missing values before cleaning
df.isna().sum()
# Out:
# state                              0
# account_length                   501
# area_code                          0
# international_plan                 0
# voice_mail_plan                    0
# number_vmail_messages            200
# total_day_minutes                200
# total_day_calls                  200
# total_day_charge                 200
# total_eve_minutes                301
# total_eve_calls                  200
# total_eve_charge                 200
# total_night_minutes              200
# total_night_calls                  0
# total_night_charge               200
# total_intl_minutes               200
# total_intl_calls                 301
# total_intl_charge                200
# number_customer_service_calls    200
# churn                              0
# dtype: int64

# %%
#Checking on the percentage of missing values per feature.
(df.isna().sum()/len(df))*100
# Out:
# state                             0.000000
# account_length                   15.031503
# area_code                         0.000000
# international_plan                0.000000
# voice_mail_plan                   0.000000
# number_vmail_messages             6.000600
# total_day_minutes                 6.000600
# total_day_calls                   6.000600
# total_day_charge                  6.000600
# total_eve_minutes                 9.030903
# total_eve_calls                   6.000600
# total_eve_charge                  6.000600
# total_night_minutes               6.000600
# total_night_calls                 0.000000
# total_night_charge                6.000600
# total_intl_minutes                6.000600
# total_intl_calls                  9.030903
# total_intl_charge                 6.000600
# number_customer_service_calls     6.000600
# churn                             0.000000
# dtype: float64

# %%
#Used padding and backfill since the data is random from different customer.
df.fillna(method = 'pad',inplace = True)
df.fillna(method = 'bfill', inplace =True)

# %%
#Check for missing values after cleaning
df.isna().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
#Transforming the categorical data to numeric
dummy = pd.get_dummies(df.loc[:,['international_plan','voice_mail_plan','churn']])

# %%
#concating my dummy data to the original dataframe
df_dummy = pd.concat([df,dummy], axis = 1)

# %%
#Keeping only the transformed dummy data
dfx = pd.get_dummies(df,columns = ['international_plan','voice_mail_plan','churn'])

# %%
dfx.head()
# Out:
#   state  account_length      area_code  number_vmail_messages  \
# 0    NV           125.0  area_code_510                    0.0
# 1    HI           108.0  area_code_415                    0.0
# 2    DC            82.0  area_code_415                    0.0
# 3    HI            82.0  area_code_408                   30.0
# 4    OH            83.0  area_code_415                    0.0
#
#    total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  \
# 0             2013.4             99.0             28.66             1107.6
# 1              291.6             99.0             49.57              221.1
# 2              300.3            109.0             51.05              181.0
# 3              110.3             71.0             18.75              182.4
# 4              337.4            120.0             57.36              227.4
#
#    total_eve_calls  total_eve_charge  ...  total_intl_minutes  \
# 0            107.0             14.93  ...                10.9
# ...

# %%
#Begin data inspection ready for feature (scaling,Normalization and Standardization)
dfx.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     3333.000000            3333.000000        3333.000000
# mean        97.966997               7.283828         419.242634
# std         47.855965              13.731863         626.614710
# min       -209.000000             -10.000000           0.000000
# 25%         72.000000               0.000000         149.600000
# 50%        101.000000               0.000000         190.400000
# 75%        128.000000              16.000000         237.700000
# max        243.000000              51.000000        2185.100000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.409241         30.624149         323.743174       100.127213
# std          20.009645          9.267653         320.044637        19.977809
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
#Plot feature distribution before rescaling
num_dfx = dfx.select_dtypes('number')
num_dfx.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'account_length'}>,
#         <AxesSubplot:title={'center':'number_vmail_messages'}>,
#         <AxesSubplot:title={'center':'total_day_minutes'}>,
#         <AxesSubplot:title={'center':'total_day_calls'}>,
#         <AxesSubplot:title={'center':'total_day_charge'}>],
#        [<AxesSubplot:title={'center':'total_eve_minutes'}>,
#         <AxesSubplot:title={'center':'total_eve_calls'}>,
#         <AxesSubplot:title={'center':'total_eve_charge'}>,
#         <AxesSubplot:title={'center':'total_night_minutes'}>,
#         <AxesSubplot:title={'center':'total_night_calls'}>],
#        [<AxesSubplot:title={'center':'total_night_charge'}>,
#         <AxesSubplot:title={'center':'total_intl_minutes'}>,
#         <AxesSubplot:title={'center':'total_intl_calls'}>,
#         <AxesSubplot:title={'center':'total_intl_charge'}>,
#         <AxesSubplot:title={'center':'number_customer_service_calls'}>],
# ...

# %%
dfx.dtypes
# Out:
# state                             object
# account_length                   float64
# area_code                         object
# number_vmail_messages            float64
# total_day_minutes                float64
# total_day_calls                  float64
# total_day_charge                 float64
# total_eve_minutes                float64
# total_eve_calls                  float64
# total_eve_charge                 float64
# total_night_minutes              float64
# total_night_calls                  int64
# total_night_charge               float64
# total_intl_minutes               float64
# total_intl_calls                 float64
# total_intl_charge                float64
# number_customer_service_calls    float64
# international_plan_no              uint8
# international_plan_yes             uint8
# voice_mail_plan_no                 uint8
# voice_mail_plan_yes                uint8
# churn_no                           uint8
# churn_yes                          uint8
# ...

# %%
#feature selection and scaling, the min and max are far apart hence the need to rescale
#Getting only numbers from my dfx dataframe 
dfb = dfx.select_dtypes('number')

# %%
dfb.head()
# Out:
#    account_length  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0           125.0                    0.0             2013.4             99.0
# 1           108.0                    0.0              291.6             99.0
# 2            82.0                    0.0              300.3            109.0
# 3            82.0                   30.0              110.3             71.0
# 4            83.0                    0.0              337.4            120.0
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             28.66             1107.6            107.0             14.93
# 1             49.57              221.1             93.0             18.79
# 2             51.05              181.0            100.0             15.39
# 3             18.75              182.4            108.0             15.50
# 4             57.36              227.4            116.0             19.33
#
# ...

# %%
len(dfb.columns)
# Out:
# 21

# %%
dataframe = dfb
array = dataframe.values

# %%
#separating array into input and output components
X = array[:,0:18]
Y = array[:,18:21]
dfc = MinMaxScaler(feature_range=(0,1))
rescaledX = dfc.fit_transform(X)

# %%
res = pd.DataFrame(rescaledX)
res.columns = [
'account_length','number_vmail_messages','total_day_minutes','total_day_calls','total_day_charge','total_eve_minutes','total_eve_calls','total_eve_charge','total_night_minutes','total_night_calls','total_intl_minutes','total_intl_calls','total_intl_charge','number_customer_service_calls','international_plan_no','international_plan_yes','voice_mail_plan_no','voice_mail_plan_yes']

# %%
res.head()
# Out:
#    account_length  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0        0.738938               0.163934           0.921422         0.600000
# 1        0.701327               0.163934           0.133449         0.600000
# 2        0.643805               0.163934           0.137431         0.660606
# 3        0.643805               0.655738           0.050478         0.430303
# 4        0.646018               0.163934           0.154409         0.727273
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0          0.480550           0.890211         0.629412          0.483015
# 1          0.831154           0.177705         0.547059          0.607894
# 2          0.855969           0.145475         0.588235          0.497897
# 3          0.314386           0.146600         0.635294          0.501456
# 4          0.961771           0.182768         0.682353          0.625364
#
# ...

# %%
res.describe() #after rescaling runs from min of 0 to max 1
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     3333.000000            3333.000000        3333.000000
# mean         0.679131               0.283341           0.191864
# std          0.105876               0.225113           0.286767
# min          0.000000               0.000000           0.000000
# 25%          0.621681               0.163934           0.068464
# 50%          0.685841               0.163934           0.087136
# 75%          0.745575               0.426230           0.108782
# max          1.000000               1.000000           1.000000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean          0.608541          0.513483           0.260202         0.588984
# std           0.121271          0.155393           0.257229         0.117517
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
len(res.columns)
# Out:
# 18

# %%
#Standardizing my data(mean =0 std 1)#There is a need to set my std to 1 because it allover
from sklearn.preprocessing import StandardScaler
array = res.values
#separating input and output
X = array[:,0:18]
Y = array[:,18:21]

# %%
dfd = StandardScaler().fit(X)
StandardisedX = dfd.transform(X)

# %%
new_data = pd.DataFrame(StandardisedX)
new_data.columns = [
'account_length','number_vmail_messages','total_day_minutes','total_day_calls','total_day_charge','total_eve_minutes','total_eve_calls','total_eve_charge','total_night_minutes','total_night_calls','total_intl_minutes','total_intl_calls','total_intl_charge','number_customer_service_calls','international_plan_no','international_plan_yes','voice_mail_plan_no','voice_mail_plan_yes']

# %%
new_data.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count    3.333000e+03           3.333000e+03       3.333000e+03
# mean     6.669333e-16          -1.239799e-16      -1.503448e-16
# std      1.000150e+00           1.000150e+00       1.000150e+00
# min     -6.415356e+00          -1.258855e+00      -6.691601e-01
# 25%     -5.426887e-01          -5.305122e-01      -4.303810e-01
# 50%      6.338726e-02          -5.305122e-01      -3.652595e-01
# 75%      6.276649e-01           6.348359e-01      -2.897632e-01
# max      3.031070e+00           3.184035e+00       2.818514e+00
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count     3.333000e+03      3.333000e+03       3.333000e+03     3.333000e+03
# mean     -4.464043e-16      2.146831e-17      -3.853970e-17     2.653310e-16
# std       1.000150e+00      1.000150e+00       1.000150e+00     1.000150e+00
# min      -5.018795e+00     -3.304908e+00      -1.011708e+00    -5.012674e+00
# ...

# %%
#Normalization;In need of a gaussian distribution hence the need to normalise my data
from sklearn.preprocessing import Normalizer
array = new_data.values
#separating input and output
X = array[:,0:18]
Y = array[:,18:21]

# %%
dfe = Normalizer().fit(X)
NormaliedX = dfe.transform(X)

# %%
new_data2 = pd.DataFrame(NormaliedX)
new_data2.columns = [
'account_length','number_vmail_messages','total_day_minutes','total_day_calls','total_day_charge','total_eve_minutes','total_eve_calls','total_eve_charge','total_night_minutes','total_night_calls','total_intl_minutes','total_intl_calls','total_intl_charge','number_customer_service_calls','international_plan_no','international_plan_yes','voice_mail_plan_no','voice_mail_plan_yes']

# %%
new_data2.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     3333.000000            3333.000000        3333.000000
# mean         0.005789              -0.019866          -0.027772
# std          0.238521               0.243790           0.205096
# min         -0.907343              -0.557744          -0.245519
# 25%         -0.140789              -0.168280          -0.124018
# 50%          0.013696              -0.125548          -0.094000
# 75%          0.158560               0.133405          -0.065660
# max          0.750087               0.799629           0.651048
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean          0.000254         -0.000829          -0.027532         0.002183
# std           0.250977          0.252754           0.206810         0.254922
# min          -0.797179         -0.764533          -0.300903        -0.825051
# ...

# %%
#Plotting my data after (rescaling,standardization and normalization)
#"number_customer_service_calls was skewed but now it is normal"
new_data2.hist(figsize=(20,20))
# Out:
# array([[<AxesSubplot:title={'center':'account_length'}>,
#         <AxesSubplot:title={'center':'number_vmail_messages'}>,
#         <AxesSubplot:title={'center':'total_day_minutes'}>,
#         <AxesSubplot:title={'center':'total_day_calls'}>],
#        [<AxesSubplot:title={'center':'total_day_charge'}>,
#         <AxesSubplot:title={'center':'total_eve_minutes'}>,
#         <AxesSubplot:title={'center':'total_eve_calls'}>,
#         <AxesSubplot:title={'center':'total_eve_charge'}>],
#        [<AxesSubplot:title={'center':'total_night_minutes'}>,
#         <AxesSubplot:title={'center':'total_night_calls'}>,
#         <AxesSubplot:title={'center':'total_intl_minutes'}>,
#         <AxesSubplot:title={'center':'total_intl_calls'}>],
#        [<AxesSubplot:title={'center':'total_intl_charge'}>,
#         <AxesSubplot:title={'center':'number_customer_service_calls'}>,
#         <AxesSubplot:title={'center':'international_plan_no'}>,
# ...

# %%
#Density plot
from matplotlib import pyplot
new_data2.plot(kind = 'density', subplots = True, layout =(6,3), sharex = False, figsize =(20,20))
pyplot.show()

# %%
#Correlation per feature
import seaborn as sb
from pandas import set_option

# %%
set_option('display.width', 100)
plt.figure(figsize = (20,20))
sb.heatmap(new_data2.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#The correlation appears to be so good in some of the features(say corr of 1) and the will need to drop one
#i.e total_intl_minutes and total_night_minutes will have to drop either before making our model
