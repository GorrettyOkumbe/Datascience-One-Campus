# %%
#importng all necessary packages for the task
import pandas as pd
#import numpy as np
from sklearn.preprocessing import OneHotEncoder #used to tranform categorical data to numeric data those that are not ordinal
from sklearn.preprocessing import MinMaxScaler #used to change scales
from sklearn.preprocessing import Normalizer #helps assume a gaussianshape

# %%
#Loading my data on jupyternotebook
FileName ='C:/Users/User/Documents/WORK SPACE/' 
FilePath ='diabetes .csv'

# %%
data = pd.read_csv(FileName + FilePath)

# %%
#printing the first 10 rows of my data set
data.head(10)
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224      F   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225      F   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6
# 7  421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8  670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 9  759      34230      F   32   3.6  28    4.0   3.8  2.0  2.4  3.8   1.0
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# 5  21.0     N
# 6  24.0     N
# 7  24.0     N
# ...

# %%
#getting a sleek info about my entire dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
#Checking for the sum of missing values per feature
data.isna().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
(data.isna().sum()/len(data))*100
# Out:
# ID           0.0
# No_Pation    0.0
# Gender       0.0
# AGE          0.0
# Urea         0.0
# Cr           0.0
# HbA1c        0.0
# Chol         0.0
# TG           0.0
# HDL          0.0
# LDL          0.0
# VLDL         0.0
# BMI          0.0
# CLASS        0.0
# dtype: float64

# %%
data.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
#Checking if there is uniformity on the categorical data ie Gender,Class
print(set(data.Gender))
print(set(data.CLASS))
# Out:
# {'f', 'F', 'M'}
# {'N', 'Y ', 'P', 'N ', 'Y'}

# %%
#Starting with the gender column finding the number of rows with f
df1 = data[data['Gender'] == 'f']

# %%
df1
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 991  195       4543      f   55   4.1  34   13.9   5.4  1.6  1.6  3.1   0.7
#
#       BMI CLASS
# 991  33.0     Y

# %%
#The small f is only on row 991 hence the need for correction to F
df2 = data['Gender'].values

# %%
df2
# Out:
# array(['F', 'M', 'F', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'F',
#        'F', 'F', 'M', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'M', 'F', 'F',
#        'M', 'M', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'F', 'F', 'M', 'M',
#        'F', 'F', 'F', 'M', 'M', 'F', 'M', 'M', 'M', 'F', 'F', 'M', 'F',
#        'M', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'F',
#        'M', 'F', 'F', 'M', 'F', 'M', 'M', 'F', 'F', 'F', 'M', 'F', 'M',
#        'F', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'F', 'F', 'F', 'M', 'M',
#        'M', 'F', 'F', 'F', 'M', 'F', 'F', 'M', 'M', 'F', 'F', 'M', 'M',
#        'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'F', 'M',
#        'F', 'M', 'M', 'F', 'F', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'F',
#        'F', 'F', 'M', 'M', 'M', 'F', 'F', 'F', 'F', 'M', 'M', 'M', 'M',
#        'M', 'M', 'M', 'F', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'F',
#        'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M',
# ...

# %%
df2[991] ='F'

# %%
#Getting the Gender back to my dataframe
data['Gender'] = df2

# %%
set(data.Gender)
# Out:
# {'F', 'M'}

# %%
#Correcting the CLASS cloumn since we have five categories
set(data.CLASS)
# Out:
# {'N', 'N ', 'P', 'Y', 'Y '}

# %%
df7 = data[data['CLASS'] == 'P']
df7
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG   HDL   LDL  \
# 103  472        463      M   34   3.9   81    6.0   6.2  3.9  0.80  1.90
# 104   85      46300      M   34   3.9   81    6.0   6.2  3.9  0.80  3.80
# 105  710      87671      M   34   3.9   81    6.0   6.2  3.9  0.80  3.80
# 106  429      48036      M   31   3.4   55    5.7   4.9  1.6  1.00  3.20
# 107  702      87667      M   31   3.4   55    5.7   4.9  1.6  1.00  3.20
# 108    4      34301      F   43   2.1   55    5.7   4.7  5.3  0.90  1.70
# 109  189      30383      M   42   5.4   53    5.8   5.9  3.7  1.30  3.10
# 110  201      45573      M   47   4.1   87    6.2   3.7  1.8  1.00  2.00
# 111  285      47069      M   50   4.3   59    6.1   4.0  3.0  1.00  1.80
# 112  393      47496      M   49   5.0   74    6.2   2.0  0.8  0.60  1.00
# 113  468        298      M   50   4.7   53    6.1   4.2  2.2  0.80  2.50
# 114  492      13281      M   49   3.5   59    6.0   4.0  2.1  1.40  1.90
# ...

# %%
#checking the columns where N has a space and it is only one row that is row 102
df3 = data[data['CLASS'] == 'N ']
df3
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 102  435      34241      M   38   6.1  83    5.4   4.5  1.7  0.9  2.8   0.8
#
#       BMI CLASS
# 102  24.6    N

# %%
#correcting row removing the space after N on row 102
df4 = data['CLASS'].values
df4
# Out:
# array(['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N ', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
df4[102] = 'N'

# %%
#getting class feature with corrected N to my dataframe
data['CLASS'] = df4

# %%
df4
# Out:
# array(['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N',
#        'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P', 'P',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
# ...

# %%
set(data.CLASS)
# Out:
# {'N', 'P', 'Y', 'Y '}

# %%
#correcting the 'Y ' with space to 'Y' and there are a total of four rows
df5 = data[data['CLASS'] == 'Y ']
df5
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y

# %%
df6 = data['CLASS'].values

# %%
df6[996:1000] = 'Y'

# %%
#getting my calss back to the original data
data['CLASS'] = df6

# %%
set(data.CLASS)
# Out:
# {'N', 'P', 'Y'}

# %%
data.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
#tranforming categorical data to numerical data starting with the Gender column
Femaledf = data[data['Gender'] == 'F']
Femaledf['Gender'] = 0
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5908/1467041869.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Femaledf['Gender'] = 0

# %%
Maledf = data[data['Gender'] == 'M']
Maledf['Gender'] = 1
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5908/992301851.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Maledf['Gender'] = 1

# %%
newdata = pd.concat(Femaledf, Maledf)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_5908/2538295032.py:1: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   newdata = pd.concat(Femaledf, Maledf)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5908/2538295032.py in <module>
# ----> 1 newdata = pd.concat(Femaledf, Maledf)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
# ...

# %%
data.head(10)
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224      F   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225      F   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6
# 7  421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8  670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 9  759      34230      F   32   3.6  28    4.0   3.8  2.0  2.4  3.8   1.0
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# 5  21.0     N
# 6  24.0     N
# 7  24.0     N
# ...
