# %% [markdown]
# <a href="https://colab.research.google.com/github/GorrettyOkumbe/Datascience-One-Campus/blob/master/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

# %%
Titanic = pd.read_csv("/content/Titanic Dataset.csv")

Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Gender
# 0         A/5 21171   7.2500   NaN        S    male
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# 4            373450   8.0500   NaN        S    male

# %%
print(Titanic.shape)



Titanic.isnull().sum()
# Out:
# (195, 12)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          156
# Embarked         0
# Gender           0
# dtype: int64

# %%
sns.heatmap(Titanic.isnull(), cmap="spring")
# Out:
# <Axes: >

# %%
Titanic.drop("Cabin", axis=1, inplace=True)

# %%
pd.get_dummies(Titanic["Gender"]).head()

sex = pd.get_dummies(Titanic["Gender"], drop_first=1)

sex.head(4)



pd.get_dummies(Titanic["Embarked"]).head(4)

arked = pd.get_dummies(Titanic["Embarked"], drop_first=1)



pclass = pd.get_dummies(Titanic["Pclass"], drop_first=1)

pclass.head(4)
# Out:
#        2      3
# 0  False   True
# 1  False  False
# 2  False   True
# 3  False  False

# %%
Titanic = pd.concat([Titanic, sex, pclass], axis=1)

Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Embarked  Gender   male      2      3   male  \
# 0         A/5 21171   7.2500        S    male   True  False   True   True
# 1          PC 17599  71.2833        C  female  False  False  False  False
# 2  STON/O2. 3101282   7.9250        S  female  False  False   True  False
# ...

# %%
Titanic = pd.read_csv("/content/Titanic Dataset.csv")

Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Gender
# 0         A/5 21171   7.2500   NaN        S    male
# 1          PC 17599  71.2833   C85        C  female
# 2  STON/O2. 3101282   7.9250   NaN        S  female
# 3            113803  53.1000  C123        S  female
# 4            373450   8.0500   NaN        S    male
